# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **SADIKSHYA SUBEDI**
#
# I am currently working as a research associate in a lab.

# %% [markdown]
# *I am interested in data science as I want to learn and use AI in research activity for anti cancer drug discovery*

# %%
(7+2)
# Out:
# 9

# %% [markdown]
# ![C018F620-5E1A-4BD8-B33B-4B18C72B2AE8.jpeg](attachment:C018F620-5E1A-4BD8-B33B-4B18C72B2AE8.jpeg)
#
# * milk
# * soda
# * water
#
# |create|markdown|
# |--------|-------|
# |Table|Nice|
